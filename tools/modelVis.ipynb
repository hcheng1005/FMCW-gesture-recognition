# %%
import torch

class FeatureExtractor(torch.nn.Module):
    def __init__(self, in_features, out_features) -> None:
        super().__init__()
        self.conv1 = torch.nn.Conv2d(in_features, 32, 3)
        self.norm1 = torch.nn.BatchNorm2d(32)
        self.pool1 = torch.nn.MaxPool2d(2)

        self.conv2 = torch.nn.Conv2d(32, 64, 3)
        self.norm2 = torch.nn.BatchNorm2d(64)
        self.pool2 = torch.nn.MaxPool2d(2)

        self.conv3 = torch.nn.Conv2d(64, 128, 3)
        self.norm3 = torch.nn.BatchNorm2d(128)
        self.pool3 = torch.nn.MaxPool2d(2)

        self.conv4 = torch.nn.Conv2d(128, 256, 3)
        self.norm4 = torch.nn.BatchNorm2d(256)
        self.pool4 = torch.nn.MaxPool2d(2)

        self.relu = torch.nn.ReLU()
        self.flatten = torch.nn.Flatten()
        self.fc = torch.nn.Linear(512, out_features)
        self.dropout = torch.nn.Dropout(0.5)

    def forward(self, x):
        x = self.conv1(x)
        x = self.norm1(x)
        x = self.relu(x)
        x = self.pool1(x)

        x = self.conv2(x)
        x = self.norm2(x)
        x = self.relu(x)
        x = self.pool2(x)

        x = self.conv3(x)
        x = self.norm3(x)
        x = self.relu(x)
        x = self.pool3(x)

        # x = self.conv4(x)
        # x = self.norm4(x)
        # x = self.relu(x)
        # x = self.pool4(x)

        x = self.flatten(x)
        x = self.fc(x)
        x = self.dropout(x)

        return x


class GestureNet(torch.nn.Module):
    def __init__(self, num_input_channels=4, num_cnn_features=256, num_rnn_hidden_size=256, num_classes=7) -> None:
        super().__init__()

        self.num_rnn_hidden_size = num_rnn_hidden_size

        self.frame_model = FeatureExtractor(num_input_channels, num_cnn_features)
        # self.frame_model = vgg11()
        # first_conv_layer = [torch.nn.Conv2d(4, 3, kernel_size=3, stride=1, padding=1, dilation=1, groups=1, bias=True)]
        # first_conv_layer.extend(list(self.frame_model.features))

        # self.frame_model.features = torch.nn.Sequential(*first_conv_layer)
        # self.frame_model.classifier[6] = torch.nn.Linear(4096, num_cnn_features)

        self.temporal_model = torch.nn.LSTM(input_size=num_cnn_features, hidden_size=num_rnn_hidden_size)

        self.fc1 = torch.nn.Linear(num_rnn_hidden_size, num_rnn_hidden_size // 2)
        self.relu = torch.nn.ReLU()
        self.fc2 = torch.nn.Linear(num_rnn_hidden_size // 2, num_classes)

    def forward(self, x):
        hidden = None

        for frame in x:
            features = self.frame_model(frame)
            features = torch.unsqueeze(features, 0)
            out, hidden = self.temporal_model(features, hidden)

        # out = torch.squeeze(out)
        out = self.fc1(out)
        out = self.relu(out)
        out = self.fc2(out)
        # out = torch.nn.Softmax(dim=1)(out)

        return out

# %%
# pip install torchsummary

# %%
pip install torchinfo
# Out:
# Requirement already satisfied: torchinfo in /home/charles/anaconda3/lib/python3.12/site-packages (1.8.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# from torchsummary import summary
from torchinfo import summary
import numpy as np 

model = GestureNet(num_input_channels=3, num_classes=12).cuda()  # 初始化模型 
summary(model, input_size=(20, 16, 3, 32, 32))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# GestureNet                               [1, 16, 12]               --
# ├─FeatureExtractor: 1-1                  [16, 256]                 295,680
# │    └─Conv2d: 2-1                       [16, 32, 30, 30]          896
# │    └─BatchNorm2d: 2-2                  [16, 32, 30, 30]          64
# │    └─ReLU: 2-3                         [16, 32, 30, 30]          --
# │    └─MaxPool2d: 2-4                    [16, 32, 15, 15]          --
# │    └─Conv2d: 2-5                       [16, 64, 13, 13]          18,496
# │    └─BatchNorm2d: 2-6                  [16, 64, 13, 13]          128
# │    └─ReLU: 2-7                         [16, 64, 13, 13]          --
# │    └─MaxPool2d: 2-8                    [16, 64, 6, 6]            --
# │    └─Conv2d: 2-9                       [16, 128, 4, 4]           73,856
# │    └─BatchNorm2d: 2-10                 [16, 128, 4, 4]           256
# │    └─ReLU: 2-11                        [16, 128, 4, 4]           --
# │    └─MaxPool2d: 2-12                   [16, 128, 2, 2]           --
# │    └─Flatten: 2-13                     [16, 512]                 --
# │    └─Linear: 2-14                      [16, 256]                 131,328
# │    └─Dropout: 2-15                     [16, 256]                 --
# ├─LSTM: 1-2                              [1, 16, 256]              526,336
# ├─FeatureExtractor: 1-3                  [16, 256]                 (recursive)
# │    └─Conv2d: 2-16                      [16, 32, 30, 30]          (recursive)
# │    └─BatchNorm2d: 2-17                 [16, 32, 30, 30]          (recursive)
# │    └─ReLU: 2-18                        [16, 32, 30, 30]          --
# │    └─MaxPool2d: 2-19                   [16, 32, 15, 15]          --
# │    └─Conv2d: 2-20                      [16, 64, 13, 13]          (recursive)
# │    └─BatchNorm2d: 2-21                 [16, 64, 13, 13]          (recursive)
# │    └─ReLU: 2-22                        [16, 64, 13, 13]          --
# │    └─MaxPool2d: 2-23                   [16, 64, 6, 6]            --
# │    └─Conv2d: 2-24                      [16, 128, 4, 4]           (recursive)
# │    └─BatchNorm2d: 2-25                 [16, 128, 4, 4]           (recursive)
# │    └─ReLU: 2-26                        [16, 128, 4, 4]           --
# │    └─MaxPool2d: 2-27                   [16, 128, 2, 2]           --
# │    └─Flatten: 2-28                     [16, 512]                 --
# │    └─Linear: 2-29                      [16, 256]                 (recursive)
# │    └─Dropout: 2-30                     [16, 256]                 --
# ├─LSTM: 1-4                              [1, 16, 256]              (recursive)
# ├─FeatureExtractor: 1-5                  [16, 256]                 (recursive)
# │    └─Conv2d: 2-31                      [16, 32, 30, 30]          (recursive)
# │    └─BatchNorm2d: 2-32                 [16, 32, 30, 30]          (recursive)
# │    └─ReLU: 2-33                        [16, 32, 30, 30]          --
# │    └─MaxPool2d: 2-34                   [16, 32, 15, 15]          --
# │    └─Conv2d: 2-35                      [16, 64, 13, 13]          (recursive)
# │    └─BatchNorm2d: 2-36                 [16, 64, 13, 13]          (recursive)
# │    └─ReLU: 2-37                        [16, 64, 13, 13]          --
# │    └─MaxPool2d: 2-38                   [16, 64, 6, 6]            --
# │    └─Conv2d: 2-39                      [16, 128, 4, 4]           (recursive)
# │    └─BatchNorm2d: 2-40                 [16, 128, 4, 4]           (recursive)
# │    └─ReLU: 2-41                        [16, 128, 4, 4]           --
# │    └─MaxPool2d: 2-42                   [16, 128, 2, 2]           --
# │    └─Flatten: 2-43                     [16, 512]                 --
# │    └─Linear: 2-44                      [16, 256]                 (recursive)
# │    └─Dropout: 2-45                     [16, 256]                 --
# ├─LSTM: 1-6                              [1, 16, 256]              (recursive)
# ├─FeatureExtractor: 1-7                  [16, 256]                 (recursive)
# │    └─Conv2d: 2-46                      [16, 32, 30, 30]          (recursive)
# │    └─BatchNorm2d: 2-47                 [16, 32, 30, 30]          (recursive)
# │    └─ReLU: 2-48                        [16, 32, 30, 30]          --
# │    └─MaxPool2d: 2-49                   [16, 32, 15, 15]          --
# │    └─Conv2d: 2-50                      [16, 64, 13, 13]          (recursive)
# │    └─BatchNorm2d: 2-51                 [16, 64, 13, 13]          (recursive)
# │    └─ReLU: 2-52                        [16, 64, 13, 13]          --
# │    └─MaxPool2d: 2-53                   [16, 64, 6, 6]            --
# │    └─Conv2d: 2-54                      [16, 128, 4, 4]           (recursive)
# │    └─BatchNorm2d: 2-55                 [16, 128, 4, 4]           (recursive)
# │    └─ReLU: 2-56                        [16, 128, 4, 4]           --
# │    └─MaxPool2d: 2-57                   [16, 128, 2, 2]           --
# │    └─Flatten: 2-58                     [16, 512]                 --
# │    └─Linear: 2-59                      [16, 256]                 (recursive)
# │    └─Dropout: 2-60                     [16, 256]                 --
# ├─LSTM: 1-8                              [1, 16, 256]              (recursive)
# ├─FeatureExtractor: 1-9                  [16, 256]                 (recursive)
# │    └─Conv2d: 2-61                      [16, 32, 30, 30]          (recursive)
# │    └─BatchNorm2d: 2-62                 [16, 32, 30, 30]          (recursive)
# │    └─ReLU: 2-63                        [16, 32, 30, 30]          --
# │    └─MaxPool2d: 2-64                   [16, 32, 15, 15]          --
# │    └─Conv2d: 2-65                      [16, 64, 13, 13]          (recursive)
# │    └─BatchNorm2d: 2-66                 [16, 64, 13, 13]          (recursive)
# │    └─ReLU: 2-67                        [16, 64, 13, 13]          --
# │    └─MaxPool2d: 2-68                   [16, 64, 6, 6]            --
# │    └─Conv2d: 2-69                      [16, 128, 4, 4]           (recursive)
# │    └─BatchNorm2d: 2-70                 [16, 128, 4, 4]           (recursive)
# │    └─ReLU: 2-71                        [16, 128, 4, 4]           --
# │    └─MaxPool2d: 2-72                   [16, 128, 2, 2]           --
# │    └─Flatten: 2-73                     [16, 512]                 --
# │    └─Linear: 2-74                      [16, 256]                 (recursive)
# │    └─Dropout: 2-75                     [16, 256]                 --
# ├─LSTM: 1-10                             [1, 16, 256]              (recursive)
# ├─FeatureExtractor: 1-11                 [16, 256]                 (recursive)
# │    └─Conv2d: 2-76                      [16, 32, 30, 30]          (recursive)
# │    └─BatchNorm2d: 2-77                 [16, 32, 30, 30]          (recursive)
# │    └─ReLU: 2-78                        [16, 32, 30, 30]          --
# │    └─MaxPool2d: 2-79                   [16, 32, 15, 15]          --
# │    └─Conv2d: 2-80                      [16, 64, 13, 13]          (recursive)
# │    └─BatchNorm2d: 2-81                 [16, 64, 13, 13]          (recursive)
# │    └─ReLU: 2-82                        [16, 64, 13, 13]          --
# │    └─MaxPool2d: 2-83                   [16, 64, 6, 6]            --
# │    └─Conv2d: 2-84                      [16, 128, 4, 4]           (recursive)
# │    └─BatchNorm2d: 2-85                 [16, 128, 4, 4]           (recursive)
# │    └─ReLU: 2-86                        [16, 128, 4, 4]           --
# │    └─MaxPool2d: 2-87                   [16, 128, 2, 2]           --
# │    └─Flatten: 2-88                     [16, 512]                 --
# │    └─Linear: 2-89                      [16, 256]                 (recursive)
# │    └─Dropout: 2-90                     [16, 256]                 --
# ├─LSTM: 1-12                             [1, 16, 256]              (recursive)
# ├─FeatureExtractor: 1-13                 [16, 256]                 (recursive)
# │    └─Conv2d: 2-91                      [16, 32, 30, 30]          (recursive)
# │    └─BatchNorm2d: 2-92                 [16, 32, 30, 30]          (recursive)
# │    └─ReLU: 2-93                        [16, 32, 30, 30]          --
# │    └─MaxPool2d: 2-94                   [16, 32, 15, 15]          --
# │    └─Conv2d: 2-95                      [16, 64, 13, 13]          (recursive)
# │    └─BatchNorm2d: 2-96                 [16, 64, 13, 13]          (recursive)
# │    └─ReLU: 2-97                        [16, 64, 13, 13]          --
# │    └─MaxPool2d: 2-98                   [16, 64, 6, 6]            --
# │    └─Conv2d: 2-99                      [16, 128, 4, 4]           (recursive)
# │    └─BatchNorm2d: 2-100                [16, 128, 4, 4]           (recursive)
# │    └─ReLU: 2-101                       [16, 128, 4, 4]           --
# │    └─MaxPool2d: 2-102                  [16, 128, 2, 2]           --
# │    └─Flatten: 2-103                    [16, 512]                 --
# │    └─Linear: 2-104                     [16, 256]                 (recursive)
# │    └─Dropout: 2-105                    [16, 256]                 --
# ├─LSTM: 1-14                             [1, 16, 256]              (recursive)
# ├─FeatureExtractor: 1-15                 [16, 256]                 (recursive)
# │    └─Conv2d: 2-106                     [16, 32, 30, 30]          (recursive)
# │    └─BatchNorm2d: 2-107                [16, 32, 30, 30]          (recursive)
# │    └─ReLU: 2-108                       [16, 32, 30, 30]          --
# │    └─MaxPool2d: 2-109                  [16, 32, 15, 15]          --
# │    └─Conv2d: 2-110                     [16, 64, 13, 13]          (recursive)
# │    └─BatchNorm2d: 2-111                [16, 64, 13, 13]          (recursive)
# │    └─ReLU: 2-112                       [16, 64, 13, 13]          --
# │    └─MaxPool2d: 2-113                  [16, 64, 6, 6]            --
# │    └─Conv2d: 2-114                     [16, 128, 4, 4]           (recursive)
# │    └─BatchNorm2d: 2-115                [16, 128, 4, 4]           (recursive)
# │    └─ReLU: 2-116                       [16, 128, 4, 4]           --
# │    └─MaxPool2d: 2-117                  [16, 128, 2, 2]           --
# │    └─Flatten: 2-118                    [16, 512]                 --
# │    └─Linear: 2-119                     [16, 256]                 (recursive)
# │    └─Dropout: 2-120                    [16, 256]                 --
# ├─LSTM: 1-16                             [1, 16, 256]              (recursive)
# ├─FeatureExtractor: 1-17                 [16, 256]                 (recursive)
# │    └─Conv2d: 2-121                     [16, 32, 30, 30]          (recursive)
# │    └─BatchNorm2d: 2-122                [16, 32, 30, 30]          (recursive)
# │    └─ReLU: 2-123                       [16, 32, 30, 30]          --
# │    └─MaxPool2d: 2-124                  [16, 32, 15, 15]          --
# │    └─Conv2d: 2-125                     [16, 64, 13, 13]          (recursive)
# │    └─BatchNorm2d: 2-126                [16, 64, 13, 13]          (recursive)
# │    └─ReLU: 2-127                       [16, 64, 13, 13]          --
# │    └─MaxPool2d: 2-128                  [16, 64, 6, 6]            --
# │    └─Conv2d: 2-129                     [16, 128, 4, 4]           (recursive)
# │    └─BatchNorm2d: 2-130                [16, 128, 4, 4]           (recursive)
# │    └─ReLU: 2-131                       [16, 128, 4, 4]           --
# │    └─MaxPool2d: 2-132                  [16, 128, 2, 2]           --
# │    └─Flatten: 2-133                    [16, 512]                 --
# │    └─Linear: 2-134                     [16, 256]                 (recursive)
# │    └─Dropout: 2-135                    [16, 256]                 --
# ├─LSTM: 1-18                             [1, 16, 256]              (recursive)
# ├─FeatureExtractor: 1-19                 [16, 256]                 (recursive)
# │    └─Conv2d: 2-136                     [16, 32, 30, 30]          (recursive)
# │    └─BatchNorm2d: 2-137                [16, 32, 30, 30]          (recursive)
# │    └─ReLU: 2-138                       [16, 32, 30, 30]          --
# │    └─MaxPool2d: 2-139                  [16, 32, 15, 15]          --
# │    └─Conv2d: 2-140                     [16, 64, 13, 13]          (recursive)
# │    └─BatchNorm2d: 2-141                [16, 64, 13, 13]          (recursive)
# │    └─ReLU: 2-142                       [16, 64, 13, 13]          --
# │    └─MaxPool2d: 2-143                  [16, 64, 6, 6]            --
# │    └─Conv2d: 2-144                     [16, 128, 4, 4]           (recursive)
# │    └─BatchNorm2d: 2-145                [16, 128, 4, 4]           (recursive)
# │    └─ReLU: 2-146                       [16, 128, 4, 4]           --
# │    └─MaxPool2d: 2-147                  [16, 128, 2, 2]           --
# │    └─Flatten: 2-148                    [16, 512]                 --
# │    └─Linear: 2-149                     [16, 256]                 (recursive)
# │    └─Dropout: 2-150                    [16, 256]                 --
# ├─LSTM: 1-20                             [1, 16, 256]              (recursive)
# ├─FeatureExtractor: 1-21                 [16, 256]                 (recursive)
# │    └─Conv2d: 2-151                     [16, 32, 30, 30]          (recursive)
# │    └─BatchNorm2d: 2-152                [16, 32, 30, 30]          (recursive)
# │    └─ReLU: 2-153                       [16, 32, 30, 30]          --
# │    └─MaxPool2d: 2-154                  [16, 32, 15, 15]          --
# │    └─Conv2d: 2-155                     [16, 64, 13, 13]          (recursive)
# │    └─BatchNorm2d: 2-156                [16, 64, 13, 13]          (recursive)
# │    └─ReLU: 2-157                       [16, 64, 13, 13]          --
# │    └─MaxPool2d: 2-158                  [16, 64, 6, 6]            --
# │    └─Conv2d: 2-159                     [16, 128, 4, 4]           (recursive)
# │    └─BatchNorm2d: 2-160                [16, 128, 4, 4]           (recursive)
# │    └─ReLU: 2-161                       [16, 128, 4, 4]           --
# │    └─MaxPool2d: 2-162                  [16, 128, 2, 2]           --
# │    └─Flatten: 2-163                    [16, 512]                 --
# │    └─Linear: 2-164                     [16, 256]                 (recursive)
# │    └─Dropout: 2-165                    [16, 256]                 --
# ├─LSTM: 1-22                             [1, 16, 256]              (recursive)
# ├─FeatureExtractor: 1-23                 [16, 256]                 (recursive)
# │    └─Conv2d: 2-166                     [16, 32, 30, 30]          (recursive)
# │    └─BatchNorm2d: 2-167                [16, 32, 30, 30]          (recursive)
# │    └─ReLU: 2-168                       [16, 32, 30, 30]          --
# │    └─MaxPool2d: 2-169                  [16, 32, 15, 15]          --
# │    └─Conv2d: 2-170                     [16, 64, 13, 13]          (recursive)
# │    └─BatchNorm2d: 2-171                [16, 64, 13, 13]          (recursive)
# │    └─ReLU: 2-172                       [16, 64, 13, 13]          --
# │    └─MaxPool2d: 2-173                  [16, 64, 6, 6]            --
# │    └─Conv2d: 2-174                     [16, 128, 4, 4]           (recursive)
# │    └─BatchNorm2d: 2-175                [16, 128, 4, 4]           (recursive)
# │    └─ReLU: 2-176                       [16, 128, 4, 4]           --
# │    └─MaxPool2d: 2-177                  [16, 128, 2, 2]           --
# │    └─Flatten: 2-178                    [16, 512]                 --
# │    └─Linear: 2-179                     [16, 256]                 (recursive)
# │    └─Dropout: 2-180                    [16, 256]                 --
# ├─LSTM: 1-24                             [1, 16, 256]              (recursive)
# ├─FeatureExtractor: 1-25                 [16, 256]                 (recursive)
# │    └─Conv2d: 2-181                     [16, 32, 30, 30]          (recursive)
# │    └─BatchNorm2d: 2-182                [16, 32, 30, 30]          (recursive)
# │    └─ReLU: 2-183                       [16, 32, 30, 30]          --
# │    └─MaxPool2d: 2-184                  [16, 32, 15, 15]          --
# │    └─Conv2d: 2-185                     [16, 64, 13, 13]          (recursive)
# │    └─BatchNorm2d: 2-186                [16, 64, 13, 13]          (recursive)
# │    └─ReLU: 2-187                       [16, 64, 13, 13]          --
# │    └─MaxPool2d: 2-188                  [16, 64, 6, 6]            --
# │    └─Conv2d: 2-189                     [16, 128, 4, 4]           (recursive)
# │    └─BatchNorm2d: 2-190                [16, 128, 4, 4]           (recursive)
# │    └─ReLU: 2-191                       [16, 128, 4, 4]           --
# │    └─MaxPool2d: 2-192                  [16, 128, 2, 2]           --
# │    └─Flatten: 2-193                    [16, 512]                 --
# │    └─Linear: 2-194                     [16, 256]                 (recursive)
# │    └─Dropout: 2-195                    [16, 256]                 --
# ├─LSTM: 1-26                             [1, 16, 256]              (recursive)
# ├─FeatureExtractor: 1-27                 [16, 256]                 (recursive)
# │    └─Conv2d: 2-196                     [16, 32, 30, 30]          (recursive)
# │    └─BatchNorm2d: 2-197                [16, 32, 30, 30]          (recursive)
# │    └─ReLU: 2-198                       [16, 32, 30, 30]          --
# │    └─MaxPool2d: 2-199                  [16, 32, 15, 15]          --
# │    └─Conv2d: 2-200                     [16, 64, 13, 13]          (recursive)
# │    └─BatchNorm2d: 2-201                [16, 64, 13, 13]          (recursive)
# │    └─ReLU: 2-202                       [16, 64, 13, 13]          --
# │    └─MaxPool2d: 2-203                  [16, 64, 6, 6]            --
# │    └─Conv2d: 2-204                     [16, 128, 4, 4]           (recursive)
# │    └─BatchNorm2d: 2-205                [16, 128, 4, 4]           (recursive)
# │    └─ReLU: 2-206                       [16, 128, 4, 4]           --
# │    └─MaxPool2d: 2-207                  [16, 128, 2, 2]           --
# │    └─Flatten: 2-208                    [16, 512]                 --
# │    └─Linear: 2-209                     [16, 256]                 (recursive)
# │    └─Dropout: 2-210                    [16, 256]                 --
# ├─LSTM: 1-28                             [1, 16, 256]              (recursive)
# ├─FeatureExtractor: 1-29                 [16, 256]                 (recursive)
# │    └─Conv2d: 2-211                     [16, 32, 30, 30]          (recursive)
# │    └─BatchNorm2d: 2-212                [16, 32, 30, 30]          (recursive)
# │    └─ReLU: 2-213                       [16, 32, 30, 30]          --
# │    └─MaxPool2d: 2-214                  [16, 32, 15, 15]          --
# │    └─Conv2d: 2-215                     [16, 64, 13, 13]          (recursive)
# │    └─BatchNorm2d: 2-216                [16, 64, 13, 13]          (recursive)
# │    └─ReLU: 2-217                       [16, 64, 13, 13]          --
# │    └─MaxPool2d: 2-218                  [16, 64, 6, 6]            --
# │    └─Conv2d: 2-219                     [16, 128, 4, 4]           (recursive)
# │    └─BatchNorm2d: 2-220                [16, 128, 4, 4]           (recursive)
# │    └─ReLU: 2-221                       [16, 128, 4, 4]           --
# │    └─MaxPool2d: 2-222                  [16, 128, 2, 2]           --
# │    └─Flatten: 2-223                    [16, 512]                 --
# │    └─Linear: 2-224                     [16, 256]                 (recursive)
# │    └─Dropout: 2-225                    [16, 256]                 --
# ├─LSTM: 1-30                             [1, 16, 256]              (recursive)
# ├─FeatureExtractor: 1-31                 [16, 256]                 (recursive)
# │    └─Conv2d: 2-226                     [16, 32, 30, 30]          (recursive)
# │    └─BatchNorm2d: 2-227                [16, 32, 30, 30]          (recursive)
# │    └─ReLU: 2-228                       [16, 32, 30, 30]          --
# │    └─MaxPool2d: 2-229                  [16, 32, 15, 15]          --
# │    └─Conv2d: 2-230                     [16, 64, 13, 13]          (recursive)
# │    └─BatchNorm2d: 2-231                [16, 64, 13, 13]          (recursive)
# │    └─ReLU: 2-232                       [16, 64, 13, 13]          --
# │    └─MaxPool2d: 2-233                  [16, 64, 6, 6]            --
# │    └─Conv2d: 2-234                     [16, 128, 4, 4]           (recursive)
# │    └─BatchNorm2d: 2-235                [16, 128, 4, 4]           (recursive)
# │    └─ReLU: 2-236                       [16, 128, 4, 4]           --
# │    └─MaxPool2d: 2-237                  [16, 128, 2, 2]           --
# │    └─Flatten: 2-238                    [16, 512]                 --
# │    └─Linear: 2-239                     [16, 256]                 (recursive)
# │    └─Dropout: 2-240                    [16, 256]                 --
# ├─LSTM: 1-32                             [1, 16, 256]              (recursive)
# ├─FeatureExtractor: 1-33                 [16, 256]                 (recursive)
# │    └─Conv2d: 2-241                     [16, 32, 30, 30]          (recursive)
# │    └─BatchNorm2d: 2-242                [16, 32, 30, 30]          (recursive)
# │    └─ReLU: 2-243                       [16, 32, 30, 30]          --
# │    └─MaxPool2d: 2-244                  [16, 32, 15, 15]          --
# │    └─Conv2d: 2-245                     [16, 64, 13, 13]          (recursive)
# │    └─BatchNorm2d: 2-246                [16, 64, 13, 13]          (recursive)
# │    └─ReLU: 2-247                       [16, 64, 13, 13]          --
# │    └─MaxPool2d: 2-248                  [16, 64, 6, 6]            --
# │    └─Conv2d: 2-249                     [16, 128, 4, 4]           (recursive)
# │    └─BatchNorm2d: 2-250                [16, 128, 4, 4]           (recursive)
# │    └─ReLU: 2-251                       [16, 128, 4, 4]           --
# │    └─MaxPool2d: 2-252                  [16, 128, 2, 2]           --
# │    └─Flatten: 2-253                    [16, 512]                 --
# │    └─Linear: 2-254                     [16, 256]                 (recursive)
# │    └─Dropout: 2-255                    [16, 256]                 --
# ├─LSTM: 1-34                             [1, 16, 256]              (recursive)
# ├─FeatureExtractor: 1-35                 [16, 256]                 (recursive)
# │    └─Conv2d: 2-256                     [16, 32, 30, 30]          (recursive)
# │    └─BatchNorm2d: 2-257                [16, 32, 30, 30]          (recursive)
# │    └─ReLU: 2-258                       [16, 32, 30, 30]          --
# │    └─MaxPool2d: 2-259                  [16, 32, 15, 15]          --
# │    └─Conv2d: 2-260                     [16, 64, 13, 13]          (recursive)
# │    └─BatchNorm2d: 2-261                [16, 64, 13, 13]          (recursive)
# │    └─ReLU: 2-262                       [16, 64, 13, 13]          --
# │    └─MaxPool2d: 2-263                  [16, 64, 6, 6]            --
# │    └─Conv2d: 2-264                     [16, 128, 4, 4]           (recursive)
# │    └─BatchNorm2d: 2-265                [16, 128, 4, 4]           (recursive)
# │    └─ReLU: 2-266                       [16, 128, 4, 4]           --
# │    └─MaxPool2d: 2-267                  [16, 128, 2, 2]           --
# │    └─Flatten: 2-268                    [16, 512]                 --
# │    └─Linear: 2-269                     [16, 256]                 (recursive)
# │    └─Dropout: 2-270                    [16, 256]                 --
# ├─LSTM: 1-36                             [1, 16, 256]              (recursive)
# ├─FeatureExtractor: 1-37                 [16, 256]                 (recursive)
# │    └─Conv2d: 2-271                     [16, 32, 30, 30]          (recursive)
# │    └─BatchNorm2d: 2-272                [16, 32, 30, 30]          (recursive)
# │    └─ReLU: 2-273                       [16, 32, 30, 30]          --
# │    └─MaxPool2d: 2-274                  [16, 32, 15, 15]          --
# │    └─Conv2d: 2-275                     [16, 64, 13, 13]          (recursive)
# │    └─BatchNorm2d: 2-276                [16, 64, 13, 13]          (recursive)
# │    └─ReLU: 2-277                       [16, 64, 13, 13]          --
# │    └─MaxPool2d: 2-278                  [16, 64, 6, 6]            --
# │    └─Conv2d: 2-279                     [16, 128, 4, 4]           (recursive)
# │    └─BatchNorm2d: 2-280                [16, 128, 4, 4]           (recursive)
# │    └─ReLU: 2-281                       [16, 128, 4, 4]           --
# │    └─MaxPool2d: 2-282                  [16, 128, 2, 2]           --
# │    └─Flatten: 2-283                    [16, 512]                 --
# │    └─Linear: 2-284                     [16, 256]                 (recursive)
# │    └─Dropout: 2-285                    [16, 256]                 --
# ├─LSTM: 1-38                             [1, 16, 256]              (recursive)
# ├─FeatureExtractor: 1-39                 [16, 256]                 (recursive)
# │    └─Conv2d: 2-286                     [16, 32, 30, 30]          (recursive)
# │    └─BatchNorm2d: 2-287                [16, 32, 30, 30]          (recursive)
# │    └─ReLU: 2-288                       [16, 32, 30, 30]          --
# │    └─MaxPool2d: 2-289                  [16, 32, 15, 15]          --
# │    └─Conv2d: 2-290                     [16, 64, 13, 13]          (recursive)
# │    └─BatchNorm2d: 2-291                [16, 64, 13, 13]          (recursive)
# │    └─ReLU: 2-292                       [16, 64, 13, 13]          --
# │    └─MaxPool2d: 2-293                  [16, 64, 6, 6]            --
# │    └─Conv2d: 2-294                     [16, 128, 4, 4]           (recursive)
# │    └─BatchNorm2d: 2-295                [16, 128, 4, 4]           (recursive)
# │    └─ReLU: 2-296                       [16, 128, 4, 4]           --
# │    └─MaxPool2d: 2-297                  [16, 128, 2, 2]           --
# │    └─Flatten: 2-298                    [16, 512]                 --
# │    └─Linear: 2-299                     [16, 256]                 (recursive)
# │    └─Dropout: 2-300                    [16, 256]                 --
# ├─LSTM: 1-40                             [1, 16, 256]              (recursive)
# ├─Linear: 1-41                           [1, 16, 128]              32,896
# ├─ReLU: 1-42                             [1, 16, 128]              --
# ├─Linear: 1-43                           [1, 16, 12]               1,548
# ==========================================================================================
# Total params: 1,081,484
# Trainable params: 1,081,484
# Non-trainable params: 0
# Total mult-adds (Units.GIGABYTES): 1.85
# ==========================================================================================
# Input size (MB): 3.93
# Forward/backward pass size (MB): 214.65
# Params size (MB): 3.14
# Estimated Total Size (MB): 221.72
# ==========================================================================================
